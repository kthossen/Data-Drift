# %%
import torch
from torch import nn
import torch.nn.functional as F
import numpy as np
from torch import optim
from torch.utils.data import DataLoader
from torch import optim

# %%
class PMDataset(Dataset):
    def __init__(self,):

        total = 1000
        seq_size = 100
        features = 100
        self.data = torch.Tensor(total, seq_size, features)

    def __len__(self):
        return self.data.shape[0]

    def __getitem__(self, idx):
        """
        """
        time_stamp = 24
        target_size = 8
        st = idx
        ed = idx + time_stamp 
        x = self.data[st:ed]
        
        st = idx + time_stamp 
        ed = idx + time_stamp + target_size
        y = self.data[st:ed]

        return  torch.FloatTensor(x),\
                torch.FloatTensor(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7d63bf07eb3f> in <module>
# ----> 1 class PMDataset(Dataset):
#       2     def __init__(self,):
#       3
#       4         total = 1000
#       5         seq_size = 100
#
# NameError: name 'Dataset' is not defined

# %%
class GRU(nn.Module):
    def __init__(self, ):
        super().__init__()
        self.rnn = nn.GRU(input_dim, 
                          output_dim, 
                          batch_first=True, 
                          num_layers=1, 
                          dropout=dropout, 
                          bidirectional=True)
        # output: [batch, feature.... ]
        self.dropout = nn.Dropout()
        self.relu = nn.ReLU()
        self.leakyrelu = nn.LeakyReLU()
    
    def forward(self, x):
        outupt, hidden = self.rnn(x)
        return outupt

class Weighted(nn.Module):
    def __init__(self, n):
        super().__init__()
        self.net = nn.Linear(n, 1)
    
    def forward(self, x):            
        return self.net(x)

# %%
dataset = PMDataset()
dataloader = DataLoader(dataset, batch_size=64, shuffle=True, drop_last=True)
model = GRU()
wrap = Weighted(3)
mse = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)
for i, itm in dataloader:
    x, y = itm
    y_pred = model(x)
    loss = mse(y_pred, y)
    wrap_loss = wrap(loss)
    optimizer.zero_grad()
    wrap_loss.backward()
    optimizer.step()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-80a24b3d5295> in <module>
# ----> 1 dataset = PMDataset()
#       2 dataloader = DataLoader(dataset, batch_size=64, shuffle=True, drop_last=True)
#       3 model = GRU()
#       4 wrap = Weighted()
#       5 mse = nn.MSELoss()
#
# NameError: name 'PMDataset' is not defined
